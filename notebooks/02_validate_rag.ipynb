# %% [markdown]
# # Validación del RAG Documental
#
# Prueba de búsqueda semántica sobre los tres pilares: normatividad, costos_operativos, gestion_activos.

# %%
import sys
sys.path.insert(0, '../backend')
from rag_service import search_documents

results = search_documents('¿Qué documentos se requieren para un despacho de carga?', pillar='normatividad')
for r in results:
    print(r['title'], '-', r['source'])
    print(r['content'][:200])
    print()
